# %% [markdown]
# # This notebook serves to perform middlebox infereces for RIPE Atlas v4 probes.
#
# Methodology:
# 1. Select RIPE Atlas v4 probes that are connected AND have an entry for the public IPv4 address in the meta file.
# Output scheduler:
# Input file:  Atlas/20210528.json
# Total probes in RIPE Atlas file (incl abandoned): 34210
# Total probes in RIPE Atlas file (connected and v4)): 11878
# Total probes selected (connected, v4 and ipv4 public ip entry): 10105
# Selected probes:  10105
#
# 2. Load RIPE Atlas meta data
# 3. Download measurement results from RIPE Atlas and read them
# 4. Show probes that claim to have successfully reached PEERING
# 5. Use meta file to check for public IPv4 address of each probe
# 6. Read tcpdump and show IP stats
# 7. Confirm traces that claim to hav reached with server-side logs and MUX info in the traces
# 8. Flag probes that did not actually reach (middlebox inbetween)

# %%
import json
import os
import ip_to_asn
from scapy.all import *

#msn_ids = [30458870, 30458871] - version1
#tcpdump = 'tcpdump_2021-05-29_135326.tap5' - version1

msn_ids = [30460770, 30460771] # - version2
tcpdump = 'tcpdump_2021-05-29_165743.tap5' # - version2

target_ip = '147.28.14.1'
peering_mux = '184.164.255.0/24'
folder_prefix = "Atlas/middlebox/"

probes_to_asn = ip_to_asn.load_probes_info('Atlas/20210528.json')
# Out:
# Done reading probes file

# %%
with open('Atlas/20210528.json',"r") as read_file:
    probes_file = json.load(read_file)
    
for probe in probes_file['objects']:
    #print(probe['address_v4'])
    #print(probe['address_v6'])
    #print()
    pass

# %%
#Some permission problem with the ripe library!

#IDs: 30458870, 30458871
from ripe.atlas.cousteau import AtlasResultsRequest, Measurement, Probe

for id in msn_ids: #two measurement ids
    if not os.path.isfile(folder_prefix + str(id) + ".json"):
        kwargs = {
            "msm_id": id,
            #        "start": datetime(2015, 05, 19),
            #        "stop": datetime(2015, 05, 20),
            #        "probe_ids": [1,2,3,4]
        }

        is_success, results = AtlasResultsRequest(**kwargs).create()

        if is_success:

            counter_success = 0
            counter_error = 0

            measurement = Measurement(id=id)

            print('Measurement: ', id)
            print('Description: ', measurement.description)
            print('Measurement state: ', measurement.status)

            # This saves the measurement data
            dump = json.dumps(results)
            with open(folder_prefix + str(id) + ".json", 'w') as my_data_file:
                my_data_file.write(dump)

            print("SUCCESS fetching RIPE Atlas measurment: ", id)
        else:
            print("ERROR fetching RIPE Atlas measurment: ", id)
    else:
        print('Files already downloaded')
# Out:
# Files already downloaded
# Files already downloaded

# %%
with open(folder_prefix + str(msn_ids[0]) + ".json","r") as read_file:
    first_file = json.load(read_file)
with open(folder_prefix + str(msn_ids[1]) + ".json","r") as read_file:
    second_file = json.load(read_file)

# %%
def collect_traces_that_reached_PEERING(file, successful_probes, successful_probes_data, total_probes):
    total_probes = total_probes + len(file)
    for probe in file:
        for hop in probe['result']:
            try:  # sometimes result looks like: {'error': 'name resolution failed: non-recoverable failure in name resolution (1)'}
                for repeated_hop in hop['result']:
                    try:  # Sometimes there is no from but instead on "x: *"
                        if target_ip in repeated_hop['from']:
                            successful_probes[probe['prb_id']] = [probe['src_addr']]
                            successful_probes_data[probe['prb_id']] = probe
                    except:
                        pass
            except:
                pass
    return total_probes, successful_probes, successful_probes_data

#1. search for Traces that claim to have reached
successful_probes = {}
successful_probes_data = {}
total_probes = 0
total_probes, successful_probes, successful_probes_data = collect_traces_that_reached_PEERING(first_file, successful_probes, successful_probes_data, total_probes)
print('Total probes in first file: ', total_probes)
print('Successful probes in first file: ', len(successful_probes))
print()
total_probes, successful_probes, successful_probes_data = collect_traces_that_reached_PEERING(second_file, successful_probes, successful_probes_data, total_probes)
print('Total probes in first & second file: ', total_probes)
print('Successful probes in first & second file: ', len(successful_probes))
# Out:
# Total probes in first file:  5675
# Successful probes in first file:  5638
#
# Total probes in first & second file:  9530
# Successful probes in first & second file:  9474

# %%
#enrich probes dict with public IPs in addition to private ones (many probes are behind a NAT). However, sometimes the IP in the RIPE Atlas result is the outgoing one so we check for both.
def find_probes_public_ip(probe_id):
    for probe in probes_file['objects']:
        if probe['id'] == probe_id:
            return probe['address_v4']
    return False

for probe in successful_probes:
    successful_probes[probe].append(find_probes_public_ip(probe))

# %%
#print pcap error log to see if kernel dropped any packets
with open(folder_prefix + tcpdump + '.err') as read_file:
       print(read_file.read())
# Out:
# tcpdump: listening on tap5, link-type EN10MB (Ethernet), capture size 262144 bytes
# 58535 packets captured
# 58582 packets received by filter
# 0 packets dropped by kernel

# %%
#2. check with tcpdump
#read pcap
scapy_cap = rdpcap(folder_prefix + tcpdump + '.pcap')

# %%
#successful_probes[probe_id] = public_ip

ips_that_reached_peering = set()
for packet in scapy_cap:
    if packet[IP].dst == '147.28.14.1':
        ips_that_reached_peering.add(packet[IP].src)
        
print('Any IP that reached peering: ', len(ips_that_reached_peering))
print('RIPE probes claimed to have reached PEERING: ', len(successful_probes))
# Out:
# Any IP that reached peering:  9341
# RIPE probes claimed to have reached PEERING:  9474

# %%
#check if RIPE probe IP can be confirmed in TCPdump
counter_server_side_check = set()
counter_found = set()
counter_not_found = set()
for probe_id in successful_probes:
    if successful_probes[probe_id][0] in ips_that_reached_peering or successful_probes[probe_id][1] in ips_that_reached_peering: # confirmed via tcpdump on server-side
        counter_found.add(probe_id)
        counter_server_side_check.add(probe_id)
    else: #could not be confirmed via server-side and need checking of the trace itself if MUX is involved.
        #print(successful_probes_data[probe_id]['result'][-1:][0]['result'][0]['from'] == target_ip)
        try:
            if successful_probes_data[probe_id]['result'][-1:][0]['result'][0]['from'] == target_ip:
                try:
                    if ip_to_asn.ip_in_prefix(successful_probes_data[probe_id]['result'][-2:][0]['result'][0]['from'], peering_mux) == True:
                        counter_found.add(probe_id)
                    else:
                        #print(successful_probes_data[probe_id]['result'])
                        counter_not_found.add(probe_id)
                except:
                    try:
                        if ip_to_asn.ip_in_prefix(successful_probes_data[probe_id]['result'][-2:][0]['result'][1]['from'], peering_mux) == True:
                            counter_found.add(probe_id)
                        else:
                            #print(successful_probes_data[probe_id]['result'])
                            counter_not_found.add(probe_id)
                    except:
                        try:
                            if ip_to_asn.ip_in_prefix(successful_probes_data[probe_id]['result'][-2:][0]['result'][2]['from'], peering_mux) == True:
                                counter_found.add(probe_id)
                            else:
                                #print(successful_probes_data[probe_id]['result'])
                                counter_not_found.add(probe_id)
                        except:
                            counter_not_found.add(probe_id)
                            #print(successful_probes_data[probe_id]['result'][-1:][0]['result'][0])
                            #print(successful_probes_data[probe_id]['result'][-2:][0]['result'][0])
                            #print(successful_probes_data[probe_id]['result'][-2:][0]['result'][1])
                            #print(successful_probes_data[probe_id]['result'][-2:][0]['result'][2])
        except:
            try:
                if successful_probes_data[probe_id]['result'][-1:][0]['result'][1]['from'] == target_ip:
                    try:
                        if ip_to_asn.ip_in_prefix(successful_probes_data[probe_id]['result'][-2:][0]['result'][0]['from'], peering_mux) == True:
                            counter_found.add(probe_id)
                        else:
                            #print(successful_probes_data[probe_id]['result'])
                            counter_not_found.add(probe_id)
                    except:
                        try:
                            if ip_to_asn.ip_in_prefix(successful_probes_data[probe_id]['result'][-2:][0]['result'][1]['from'], peering_mux) == True:
                                counter_found.add(probe_id)
                            else:
                                #print(successful_probes_data[probe_id]['result'])
                                counter_not_found.add(probe_id)
                        except:
                            try:
                                if ip_to_asn.ip_in_prefix(successful_probes_data[probe_id]['result'][-2:][0]['result'][2]['from'], peering_mux) == True:
                                    counter_found.add(probe_id)
                                else:
                                    #print(successful_probes_data[probe_id]['result'])
                                    counter_not_found.add(probe_id)
                            except:
                                counter_not_found.add(probe_id)
                                print(successful_probes_data[probe_id]['result'][-1:][0]['result'][0])
                                print(successful_probes_data[probe_id]['result'][-2:][0]['result'][0])
                                print(successful_probes_data[probe_id]['result'][-2:][0]['result'][1])
                                print(successful_probes_data[probe_id]['result'][-2:][0]['result'][2])
            except:
                try:
                    if successful_probes_data[probe_id]['result'][-1:][0]['result'][1]['from'] == target_ip:
                        try:
                            if ip_to_asn.ip_in_prefix(successful_probes_data[probe_id]['result'][-2:][0]['result'][0]['from'], peering_mux) == True:
                                counter_found.add(probe_id)
                            else:
                                #print(successful_probes_data[probe_id]['result'])
                                counter_not_found.add(probe_id)
                        except:
                            try:
                                if ip_to_asn.ip_in_prefix(successful_probes_data[probe_id]['result'][-2:][0]['result'][1]['from'], peering_mux) == True:
                                    counter_found.add(probe_id)
                                else:
                                    #print(successful_probes_data[probe_id]['result'])
                                    counter_not_found.add(probe_id)
                            except:
                                try:
                                    if ip_to_asn.ip_in_prefix(successful_probes_data[probe_id]['result'][-2:][0]['result'][2]['from'], peering_mux) == True:
                                        counter_found.add(probe_id)
                                    else:
                                        #print(successful_probes_data[probe_id]['result'])
                                        counter_not_found.add(probe_id)
                                except:
                                    counter_not_found.add(probe_id)
                                    print(successful_probes_data[probe_id]['result'][-1:][0]['result'][0])
                                    print(successful_probes_data[probe_id]['result'][-2:][0]['result'][0])
                                    print(successful_probes_data[probe_id]['result'][-2:][0]['result'][1])
                                    print(successful_probes_data[probe_id]['result'][-2:][0]['result'][2])
                except:
                    print('Except!')
                    print()
                    #print(successful_probes_data[probe_id]['result'][-2:][0]['result'][2])
                    #print(successful_probes[probe_id])
                    #print(successful_probes_data[probe_id]['from'])
                    print(successful_probes_data[probe_id])


print('Probes confirmed via server-side: ', len(counter_server_side_check))
print('Probes confirmed (server-side + MUX-check): ', len(counter_found))
print('Probes NOT confirmed: ', len(counter_not_found))
# Out:
# Probes confirmed via server-side:  9045
# Probes confirmed (server-side + MUX-check):  9367
# Probes NOT confirmed:  107

# %%
#show probe races that are behind a middlebox:

for id in counter_not_found:
    print('ProbeID: ', id)
    print(successful_probes_data[id])
    print()
# Out:
# ProbeID:  16896
# {'fw': 5020, 'mver': '2.2.1', 'lts': 48, 'endtime': 1622307538, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '172.16.0.107', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '172.16.0.1', 'ttl': 64, 'size': 76, 'rtt': 1.561}, {'from': '172.16.0.1', 'ttl': 64, 'size': 76, 'rtt': 0.669}, {'from': '172.16.0.1', 'ttl': 64, 'size': 76, 'rtt': 0.626}]}, {'hop': 2, 'result': [{'from': '192.168.2.1', 'ttl': 63, 'size': 76, 'rtt': 2.953}, {'from': '192.168.2.1', 'ttl': 63, 'size': 76, 'rtt': 1.299}, {'from': '192.168.2.1', 'ttl': 63, 'size': 76, 'rtt': 1.149}]}, {'hop': 3, 'result': [{'from': '192.0.0.1', 'ttl': 253, 'size': 76, 'rtt': 6.374}, {'from': '192.0.0.1', 'ttl': 253, 'size': 76, 'rtt': 3.168}, {'from': '192.0.0.1', 'ttl': 253, 'size': 76, 'rtt': 3.109}]}, {'hop': 4, 'result': [{'x': '*'}, {'x': '*'}, {'x': '*'}]}, {'hop': 5, 'result': [{'x': '*'}, {'x': '*'}, {'x': '*'}]}, {'hop': 6, 'result': [{'x': '*'}, {'x': '*'}, {'x': '*'}]}, {'hop': 7, 'result': [{'x': '*'}, {'x': '*'}, {'x': '*'}]}, {'hop': 8, 'result': [{'x': '*'}, {'x': '*'}, {'x': '*'}]}, {'hop': 255, 'result': [{'from': '147.28.14.1', 'ttl': 48, 'size': 48, 'rtt': 342.159}, {'from': '147.28.14.1', 'ttl': 48, 'size': 48, 'rtt': 430.783}, {'from': '147.28.14.1', 'ttl': 48, 'size': 48, 'rtt': 526.54}]}], 'msm_id': 30460770, 'prb_id': 16896, 'timestamp': 1622307477, 'msm_name': 'Traceroute', 'from': '184.100.19.154', 'type': 'traceroute', 'group_id': 30460770, 'stored_timestamp': 1622307539}
#
# ProbeID:  12802
# {'fw': 5020, 'mver': '2.2.1', 'lts': 47, 'endtime': 1622307495, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '192.168.2.5', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '192.168.2.1', 'ttl': 255, 'size': 28, 'rtt': 1.554}, {'from': '192.168.2.1', 'ttl': 255, 'size': 28, 'rtt': 1.338}, {'from': '192.168.2.1', 'ttl': 255, 'size': 28, 'rtt': 1.313}]}, {'hop': 2, 'result': [{'from': '192.168.1.1', 'ttl': 63, 'size': 76, 'rtt': 0.474}, {'from': '192.168.1.1', 'ttl': 63, 'size': 76, 'rtt': 0.44}, {'from': '192.168.1.1', 'ttl': 63, 'size': 76, 'rtt': 0.44}]}, {'hop': 3, 'result': [{'from': '147.28.14.1', 'ttl': 253, 'size': 48, 'tos': 192, 'rtt': 7.782}, {'from': '147.28.14.1', 'ttl': 253, 'size': 48, 'tos': 192, 'rtt': 2.122}, {'from': '147.28.14.1', 'ttl': 253, 'size': 48, 'tos': 192, 'rtt': 2.158}]}], 'msm_id': 30460770, 'prb_id': 12802, 'timestamp': 1622307494, 'msm_name': 'Traceroute', 'from': '173.79.10.18', 'type': 'traceroute', 'group_id': 30460770, 'stored_timestamp': 1622307500}
#
# ProbeID:  52227
# {'fw': 5020, 'mver': '2.2.1', 'lts': 32, 'endtime': 1622307478, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '192.168.1.30', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 1.272}, {'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 0.832}, {'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 0.73}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 1.678}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 1.613}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 1.418}]}], 'msm_id': 30460771, 'prb_id': 52227, 'timestamp': 1622307478, 'msm_name': 'Traceroute', 'from': '74.96.211.25', 'type': 'traceroute', 'group_id': 30460771, 'stored_timestamp': 1622307478}
#
# ProbeID:  14340
# {'fw': 5020, 'mver': '2.2.1', 'lts': 25, 'endtime': 1622307477, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '192.168.1.160', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 0.786}, {'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 0.557}, {'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 0.493}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 3.001}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 1.372}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 1.275}]}], 'msm_id': 30460770, 'prb_id': 14340, 'timestamp': 1622307477, 'msm_name': 'Traceroute', 'from': '141.157.220.146', 'type': 'traceroute', 'group_id': 30460770, 'stored_timestamp': 1622307477}
#
# ProbeID:  13838
# {'fw': 5020, 'mver': '2.2.1', 'lts': 14, 'endtime': 1622307476, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '192.168.1.13', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 9.473}, {'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 0.542}, {'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 0.535}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 7.499}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 9.747}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 8.99}]}], 'msm_id': 30460770, 'prb_id': 13838, 'timestamp': 1622307476, 'msm_name': 'Traceroute', 'from': '72.76.184.201', 'type': 'traceroute', 'group_id': 30460770, 'stored_timestamp': 1622307477}
#
# ProbeID:  3600
# {'fw': 4790, 'lts': 2, 'endtime': 1622307503, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '10.0.3.241', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '10.0.3.1', 'ttl': 64, 'size': 76, 'rtt': 22.838}, {'from': '10.0.3.1', 'ttl': 64, 'size': 76, 'rtt': 1.684}, {'from': '10.0.3.1', 'ttl': 64, 'size': 76, 'rtt': 1.511}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'rtt': 3.669}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'rtt': 5.258}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'rtt': 8.172}]}], 'msm_id': 30460770, 'prb_id': 3600, 'timestamp': 1622307503, 'msm_name': 'Traceroute', 'from': '74.104.157.60', 'type': 'traceroute', 'group_id': 30460770, 'stored_timestamp': 1622307512}
#
# ProbeID:  15387
# {'fw': 5020, 'mver': '2.2.1', 'lts': 41, 'endtime': 1622307480, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '192.168.1.227', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 0.799}, {'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 0.51}, {'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 0.451}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 6.382}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 9.689}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 9.133}]}], 'msm_id': 30460770, 'prb_id': 15387, 'timestamp': 1622307480, 'msm_name': 'Traceroute', 'from': '173.56.28.138', 'type': 'traceroute', 'group_id': 30460770, 'stored_timestamp': 1622307481}
#
# ProbeID:  50205
# {'fw': 5020, 'mver': '2.2.1', 'lts': 53, 'endtime': 1622307546, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '192.168.2.101', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '192.168.2.1', 'ttl': 30, 'size': 28, 'rtt': 1.62, 'ittl': 0}, {'from': '192.168.2.1', 'ttl': 30, 'size': 28, 'rtt': 1.143, 'ittl': 0}, {'from': '192.168.2.1', 'ttl': 30, 'size': 28, 'rtt': 1.102, 'ittl': 0}]}, {'hop': 2, 'result': [{'from': '113.199.128.1', 'ttl': 254, 'size': 28, 'rtt': 35.169}, {'from': '10.26.200.10', 'ttl': 126, 'size': 28, 'rtt': 36.049, 'ittl': 0}, {'from': '10.26.200.10', 'ttl': 126, 'size': 28, 'rtt': 34.335, 'ittl': 0}]}, {'hop': 3, 'result': [{'from': '202.70.72.178', 'ttl': 252, 'size': 28, 'rtt': 37.008}, {'from': '202.70.72.178', 'ttl': 252, 'size': 28, 'rtt': 35.944}, {'from': '202.70.72.178', 'ttl': 252, 'size': 28, 'rtt': 36.312}]}, {'hop': 4, 'result': [{'from': '202.70.93.81', 'ttl': 251, 'size': 28, 'rtt': 34.297}, {'from': '202.70.93.81', 'ttl': 251, 'size': 28, 'rtt': 34.672}, {'from': '202.70.93.81', 'ttl': 251, 'size': 28, 'rtt': 33.605}]}, {'hop': 5, 'result': [{'from': '202.70.93.228', 'ttl': 250, 'size': 28, 'rtt': 34.081}, {'from': '202.70.93.228', 'ttl': 250, 'size': 28, 'rtt': 41.852}, {'from': '202.70.93.228', 'ttl': 250, 'size': 28, 'rtt': 36.071}]}, {'hop': 6, 'result': [{'from': '202.70.93.201', 'ttl': 248, 'size': 28, 'rtt': 40.137}, {'from': '202.70.93.201', 'ttl': 248, 'size': 28, 'rtt': 42.793}, {'from': '202.70.93.201', 'ttl': 248, 'size': 28, 'rtt': 38.156}]}, {'hop': 7, 'result': [{'from': '180.87.34.218', 'ttl': 248, 'size': 28, 'rtt': 88.135}, {'from': '180.87.34.218', 'ttl': 248, 'size': 28, 'rtt': 88.636}, {'from': '180.87.34.218', 'ttl': 248, 'size': 28, 'rtt': 88.448}]}, {'hop': 8, 'result': [{'x': '*'}, {'x': '*'}, {'x': '*'}]}, {'hop': 9, 'result': [{'x': '*'}, {'x': '*'}, {'x': '*'}]}, {'hop': 10, 'result': [{'x': '*'}, {'x': '*'}, {'x': '*'}]}, {'hop': 11, 'result': [{'x': '*'}, {'x': '*'}, {'x': '*'}]}, {'hop': 12, 'result': [{'x': '*'}, {'x': '*'}, {'x': '*'}]}, {'hop': 255, 'result': [{'from': '147.28.14.1', 'ttl': 48, 'size': 48, 'rtt': 243.267}, {'from': '147.28.14.1', 'ttl': 48, 'size': 48, 'rtt': 240.254}, {'from': '147.28.14.1', 'ttl': 48, 'size': 48, 'rtt': 240.037}]}], 'msm_id': 30460771, 'prb_id': 50205, 'timestamp': 1622307484, 'msm_name': 'Traceroute', 'from': '113.199.166.246', 'type': 'traceroute', 'group_id': 30460771, 'stored_timestamp': 1622307548}
#
# ProbeID:  53793
# {'fw': 5020, 'mver': '2.2.1', 'lts': 11, 'endtime': 1622307486, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '10.6.8.2', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '10.6.8.1', 'ttl': 64, 'size': 28, 'rtt': 1.161}, {'from': '10.6.8.1', 'ttl': 64, 'size': 28, 'rtt': 0.654}, {'from': '10.6.8.1', 'ttl': 64, 'size': 28, 'rtt': 0.612}]}, {'hop': 2, 'result': [{'from': '10.224.128.1', 'ttl': 254, 'size': 28, 'rtt': 13.301}, {'from': '10.224.128.1', 'ttl': 254, 'size': 28, 'rtt': 11.565}, {'from': '10.224.128.1', 'ttl': 254, 'size': 28, 'rtt': 12.379}]}, {'hop': 3, 'result': [{'from': '217.72.74.225', 'ttl': 253, 'size': 68, 'rtt': 17.743}, {'from': '217.72.74.225', 'ttl': 253, 'size': 68, 'rtt': 14.288}, {'from': '217.72.74.225', 'ttl': 253, 'size': 68, 'rtt': 11.571}]}, {'hop': 4, 'result': [{'from': '185.66.149.28', 'ttl': 251, 'size': 140, 'rtt': 12.621, 'icmpext': {'version': 0, 'rfc4884': 1, 'obj': [{'class': 0, 'type': 0}]}}, {'from': '185.66.149.28', 'ttl': 251, 'size': 140, 'rtt': 7.355, 'icmpext': {'version': 0, 'rfc4884': 1, 'obj': [{'class': 0, 'type': 0}]}}, {'from': '185.66.149.28', 'ttl': 251, 'size': 140, 'rtt': 12.454, 'icmpext': {'version': 0, 'rfc4884': 1, 'obj': [{'class': 0, 'type': 0}]}}]}, {'hop': 5, 'result': [{'from': '185.66.149.52', 'ttl': 251, 'size': 68, 'rtt': 13.156}, {'from': '185.66.149.52', 'ttl': 251, 'size': 68, 'rtt': 10.8}, {'from': '185.66.149.52', 'ttl': 251, 'size': 68, 'rtt': 11.453}]}, {'hop': 6, 'result': [{'from': '147.28.14.1', 'ttl': 56, 'size': 48, 'rtt': 60.402}, {'from': '147.28.14.1', 'ttl': 56, 'size': 48, 'rtt': 63.424}, {'from': '147.28.14.1', 'ttl': 56, 'size': 48, 'rtt': 59.319}]}], 'msm_id': 30460771, 'prb_id': 53793, 'timestamp': 1622307486, 'msm_name': 'Traceroute', 'from': '178.58.123.133', 'type': 'traceroute', 'group_id': 30460771, 'stored_timestamp': 1622307488}
#
# ProbeID:  33318
# {'fw': 4770, 'lts': 35, 'endtime': 1622307476, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '192.168.88.18', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '192.168.88.1', 'ttl': 64, 'size': 76, 'rtt': 1.138}, {'from': '192.168.88.1', 'ttl': 64, 'size': 76, 'rtt': 0.406}, {'from': '192.168.88.1', 'ttl': 64, 'size': 76, 'rtt': 0.326}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 63, 'size': 48, 'rtt': 107.063}, {'from': '147.28.14.1', 'ttl': 63, 'size': 48, 'rtt': 105.434}, {'from': '147.28.14.1', 'ttl': 63, 'size': 48, 'rtt': 99.877}]}], 'msm_id': 30460771, 'prb_id': 33318, 'timestamp': 1622307476, 'msm_name': 'Traceroute', 'from': '213.87.86.203', 'type': 'traceroute', 'group_id': 30460771, 'stored_timestamp': 1622307478}
#
# ProbeID:  34856
# {'fw': 5020, 'mver': '2.2.1', 'lts': 112, 'endtime': 1622307476, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '192.168.86.4', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 3.412}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 1.245}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 1.504}]}], 'msm_id': 30460771, 'prb_id': 34856, 'timestamp': 1622307476, 'msm_name': 'Traceroute', 'from': '70.106.247.77', 'type': 'traceroute', 'group_id': 30460771, 'stored_timestamp': 1622307477}
#
# ProbeID:  52777
# {'fw': 5020, 'mver': '2.2.1', 'lts': 65, 'endtime': 1622307516, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '192.168.1.10', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '192.168.1.1', 'ttl': 255, 'size': 28, 'rtt': 1.169}, {'from': '192.168.1.1', 'ttl': 255, 'size': 28, 'rtt': 0.788}, {'from': '192.168.1.1', 'ttl': 255, 'size': 28, 'rtt': 0.711}]}, {'hop': 2, 'result': [{'x': '*'}, {'x': '*'}, {'x': '*'}]}, {'hop': 3, 'result': [{'from': '10.255.254.254', 'ttl': 253, 'size': 28, 'rtt': 7.68, 'itos': 64}, {'from': '10.255.254.254', 'ttl': 253, 'size': 28, 'rtt': 7.53, 'itos': 64}, {'from': '10.255.254.254', 'ttl': 253, 'size': 28, 'rtt': 7.107, 'itos': 64}]}, {'hop': 4, 'result': [{'from': '94.136.1.81', 'ttl': 252, 'size': 28, 'rtt': 6.785, 'itos': 64}, {'from': '94.136.1.81', 'ttl': 252, 'size': 28, 'rtt': 7.608, 'itos': 64}, {'from': '94.136.1.81', 'ttl': 252, 'size': 28, 'rtt': 7.504, 'itos': 64}]}, {'hop': 5, 'result': [{'from': '94.136.0.190', 'ttl': 251, 'size': 28, 'rtt': 7.357, 'itos': 64}, {'from': '94.136.0.190', 'ttl': 251, 'size': 28, 'rtt': 6.845, 'itos': 64}, {'from': '94.136.0.190', 'ttl': 251, 'size': 28, 'rtt': 7.205, 'itos': 64}]}, {'hop': 6, 'result': [{'from': '94.136.0.3', 'ttl': 251, 'size': 28, 'rtt': 7.066, 'itos': 64}, {'from': '94.136.0.3', 'ttl': 251, 'size': 28, 'rtt': 6.64, 'itos': 64}, {'from': '94.136.0.3', 'ttl': 251, 'size': 28, 'rtt': 7.063, 'itos': 64}]}, {'hop': 7, 'result': [{'from': '212.69.163.185', 'ttl': 249, 'size': 28, 'rtt': 7.092, 'itos': 64}, {'from': '212.69.163.185', 'ttl': 249, 'size': 28, 'rtt': 37.766, 'itos': 64}, {'from': '212.69.163.185', 'ttl': 249, 'size': 28, 'rtt': 7.355, 'itos': 64}]}, {'hop': 8, 'result': [{'from': '83.167.56.154', 'ttl': 249, 'size': 28, 'rtt': 30.173, 'itos': 64}, {'from': '83.167.56.154', 'ttl': 249, 'size': 28, 'rtt': 30.781, 'itos': 64}, {'from': '83.167.56.154', 'ttl': 249, 'size': 28, 'rtt': 30.475, 'itos': 64}]}, {'hop': 9, 'result': [{'x': '*'}, {'x': '*'}, {'x': '*'}]}, {'hop': 10, 'result': [{'from': '147.28.14.1', 'ttl': 50, 'size': 48, 'tos': 64, 'rtt': 56.371}, {'from': '147.28.14.1', 'ttl': 50, 'size': 48, 'tos': 64, 'rtt': 56.107}, {'from': '147.28.14.1', 'ttl': 50, 'size': 48, 'tos': 64, 'rtt': 56.041}]}], 'msm_id': 30460771, 'prb_id': 52777, 'timestamp': 1622307491, 'msm_name': 'Traceroute', 'from': '77.117.192.246', 'type': 'traceroute', 'group_id': 30460771, 'stored_timestamp': 1622307523}
#
# ProbeID:  54324
# {'fw': 5020, 'mver': '2.2.1', 'lts': 27, 'endtime': 1622307477, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '192.168.1.180', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 1.374}, {'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 0.798}, {'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 0.764}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 7.731}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 11.432}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 9.472}]}], 'msm_id': 30460771, 'prb_id': 54324, 'timestamp': 1622307477, 'msm_name': 'Traceroute', 'from': '74.102.148.64', 'type': 'traceroute', 'group_id': 30460771, 'stored_timestamp': 1622307477}
#
# ProbeID:  30261
# {'fw': 5020, 'mver': '2.2.1', 'lts': 132, 'endtime': 1622307477, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '192.168.1.152', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 1.551}, {'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 0.765}, {'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 0.759}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 19.495}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 41.763}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 26.307}]}], 'msm_id': 30460770, 'prb_id': 30261, 'timestamp': 1622307476, 'msm_name': 'Traceroute', 'from': '100.0.89.173', 'type': 'traceroute', 'group_id': 30460770, 'stored_timestamp': 1622307477}
#
# ProbeID:  32827
# {'fw': 5020, 'mver': '2.2.1', 'lts': 1, 'endtime': 1622307479, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '10.0.1.18', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '10.0.1.1', 'ttl': 64, 'size': 76, 'rtt': 0.88}, {'from': '10.0.1.1', 'ttl': 64, 'size': 76, 'rtt': 0.761}, {'from': '10.0.1.1', 'ttl': 64, 'size': 76, 'rtt': 0.724}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 6.761}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 9.398}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 10.611}]}], 'msm_id': 30460770, 'prb_id': 32827, 'timestamp': 1622307479, 'msm_name': 'Traceroute', 'from': '141.154.49.199', 'type': 'traceroute', 'group_id': 30460770, 'stored_timestamp': 1622307480}
#
# ProbeID:  50235
# {'fw': 5020, 'mver': '2.2.1', 'lts': 32, 'endtime': 1622307476, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '192.168.1.3', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 1.379}, {'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 0.88}, {'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 0.778}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 6.733}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 11.404}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 6.704}]}], 'msm_id': 30460771, 'prb_id': 50235, 'timestamp': 1622307476, 'msm_name': 'Traceroute', 'from': '68.129.29.3', 'type': 'traceroute', 'group_id': 30460771, 'stored_timestamp': 1622307477}
#
# ProbeID:  50751
# {'fw': 5020, 'mver': '2.2.1', 'lts': 34, 'endtime': 1622307477, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '192.168.0.235', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '192.168.0.1', 'ttl': 64, 'size': 76, 'rtt': 0.668}, {'from': '192.168.0.1', 'ttl': 64, 'size': 76, 'rtt': 0.414}, {'from': '192.168.0.1', 'ttl': 64, 'size': 76, 'rtt': 0.402}]}, {'hop': 2, 'result': [{'from': '192.168.10.1', 'ttl': 63, 'size': 76, 'rtt': 0.947}, {'from': '192.168.10.1', 'ttl': 63, 'size': 76, 'rtt': 0.807}, {'from': '192.168.10.1', 'ttl': 63, 'size': 76, 'rtt': 0.758}]}, {'hop': 3, 'result': [{'from': '147.28.14.1', 'ttl': 253, 'size': 48, 'tos': 192, 'rtt': 3.165}, {'from': '147.28.14.1', 'ttl': 253, 'size': 48, 'tos': 192, 'rtt': 2.298}, {'from': '147.28.14.1', 'ttl': 253, 'size': 48, 'tos': 192, 'rtt': 5.0}]}], 'msm_id': 30460771, 'prb_id': 50751, 'timestamp': 1622307477, 'msm_name': 'Traceroute', 'from': '68.132.52.200', 'type': 'traceroute', 'group_id': 30460771, 'stored_timestamp': 1622307477}
#
# ProbeID:  3649
# {'fw': 4790, 'lts': 8, 'endtime': 1622307484, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '172.30.246.17', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '172.30.246.1', 'ttl': 64, 'size': 76, 'rtt': 15.276}, {'from': '172.30.246.1', 'ttl': 64, 'size': 76, 'rtt': 1.127}, {'from': '172.30.246.1', 'ttl': 64, 'size': 76, 'rtt': 1.125}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'rtt': 1.853}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'rtt': 3.102}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'rtt': 14.092}]}], 'msm_id': 30460770, 'prb_id': 3649, 'timestamp': 1622307484, 'msm_name': 'Traceroute', 'from': '173.73.209.185', 'type': 'traceroute', 'group_id': 30460770, 'stored_timestamp': 1622307483}
#
# ProbeID:  52296
# {'fw': 5020, 'mver': '2.2.1', 'lts': 45, 'endtime': 1622307478, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '192.168.11.48', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '192.168.11.1', 'ttl': 64, 'size': 76, 'rtt': 1.386}, {'from': '192.168.11.1', 'ttl': 64, 'size': 76, 'rtt': 0.569}, {'from': '192.168.11.1', 'ttl': 64, 'size': 76, 'rtt': 0.516}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 1.116}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 2.674}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 2.218}]}], 'msm_id': 30460771, 'prb_id': 52296, 'timestamp': 1622307478, 'msm_name': 'Traceroute', 'from': '72.76.16.247', 'type': 'traceroute', 'group_id': 30460771, 'stored_timestamp': 1622307478}
#
# ProbeID:  30797
# {'fw': 5020, 'mver': '2.2.1', 'lts': 34, 'endtime': 1622307475, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '172.16.20.8', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '172.16.20.1', 'ttl': 64, 'size': 76, 'rtt': 1.261}, {'from': '172.16.20.1', 'ttl': 64, 'size': 76, 'rtt': 0.372}, {'from': '172.16.20.1', 'ttl': 64, 'size': 76, 'rtt': 0.312}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 3.361}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 3.085}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 3.24}]}], 'msm_id': 30460770, 'prb_id': 30797, 'timestamp': 1622307475, 'msm_name': 'Traceroute', 'from': '96.244.186.28', 'type': 'traceroute', 'group_id': 30460770, 'stored_timestamp': 1622307477}
#
# ProbeID:  27728
# {'fw': 5020, 'mver': '2.2.1', 'lts': 35, 'endtime': 1622307488, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '192.168.1.4', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '192.168.1.1', 'ttl': 254, 'size': 28, 'rtt': 1.554}, {'from': '192.168.1.1', 'ttl': 254, 'size': 28, 'rtt': 0.75}, {'from': '192.168.1.1', 'ttl': 254, 'size': 28, 'rtt': 0.707}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 4.479}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 3.503}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 3.997}]}], 'msm_id': 30460770, 'prb_id': 27728, 'timestamp': 1622307488, 'msm_name': 'Traceroute', 'from': '96.235.140.32', 'type': 'traceroute', 'group_id': 30460770, 'stored_timestamp': 1622307494}
#
# ProbeID:  21074
# {'fw': 5020, 'mver': '2.2.1', 'lts': 139, 'endtime': 1622307477, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '192.168.102.78', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '192.168.102.254', 'ttl': 255, 'size': 28, 'rtt': 0.944}, {'from': '192.168.102.254', 'ttl': 255, 'size': 28, 'rtt': 8.609}, {'from': '192.168.102.254', 'ttl': 255, 'size': 28, 'rtt': 0.806}]}, {'hop': 2, 'result': [{'from': '10.40.175.253', 'ttl': 254, 'size': 28, 'rtt': 0.401}, {'from': '10.40.175.253', 'ttl': 254, 'size': 28, 'rtt': 0.403}, {'from': '10.40.175.253', 'ttl': 254, 'size': 28, 'rtt': 0.371}]}, {'hop': 3, 'result': [{'from': '147.28.14.1', 'ttl': 253, 'size': 48, 'tos': 192, 'rtt': 2.508}, {'from': '147.28.14.1', 'ttl': 253, 'size': 48, 'tos': 192, 'rtt': 3.19}, {'from': '147.28.14.1', 'ttl': 253, 'size': 48, 'tos': 192, 'rtt': 1.07}]}], 'msm_id': 30460770, 'prb_id': 21074, 'timestamp': 1622307477, 'msm_name': 'Traceroute', 'from': '173.49.196.121', 'type': 'traceroute', 'group_id': 30460770, 'stored_timestamp': 1622307478}
#
# ProbeID:  50259
# {'fw': 5020, 'mver': '2.2.1', 'lts': 12, 'endtime': 1622307480, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '192.168.6.2', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '192.168.6.1', 'ttl': 64, 'size': 76, 'rtt': 1.319}, {'from': '192.168.6.1', 'ttl': 64, 'size': 76, 'rtt': 0.787}, {'from': '192.168.6.1', 'ttl': 64, 'size': 76, 'rtt': 0.693}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 2.17}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 3.475}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 2.732}]}], 'msm_id': 30460771, 'prb_id': 50259, 'timestamp': 1622307480, 'msm_name': 'Traceroute', 'from': '108.53.134.85', 'type': 'traceroute', 'group_id': 30460771, 'stored_timestamp': 1622307481}
#
# ProbeID:  1127
# {'fw': 4790, 'lts': 9, 'endtime': 1622307487, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '172.16.249.10', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '172.16.249.1', 'ttl': 64, 'size': 76, 'rtt': 7.406}, {'from': '172.16.249.1', 'ttl': 64, 'size': 76, 'rtt': 1.151}, {'from': '172.16.249.1', 'ttl': 64, 'size': 76, 'rtt': 1.153}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'rtt': 2.43}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'rtt': 2.127}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'rtt': 3.487}]}], 'msm_id': 30460770, 'prb_id': 1127, 'timestamp': 1622307487, 'msm_name': 'Traceroute', 'from': '100.36.70.152', 'type': 'traceroute', 'group_id': 30460770, 'stored_timestamp': 1622307490}
#
# ProbeID:  15976
# {'fw': 5020, 'mver': '2.2.1', 'lts': 4, 'endtime': 1622307477, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '192.168.100.101', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '192.168.100.1', 'ttl': 64, 'size': 76, 'rtt': 4.016}, {'from': '192.168.100.1', 'ttl': 64, 'size': 76, 'rtt': 0.402}, {'from': '192.168.100.1', 'ttl': 64, 'size': 76, 'rtt': 0.316}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 1.191}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 1.175}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 1.459}]}], 'msm_id': 30460770, 'prb_id': 15976, 'timestamp': 1622307477, 'msm_name': 'Traceroute', 'from': '100.36.38.11', 'type': 'traceroute', 'group_id': 30460770, 'stored_timestamp': 1622307477}
#
# ProbeID:  32368
# {'fw': 5020, 'mver': '2.2.1', 'lts': 23, 'endtime': 1622307475, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '10.20.30.16', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '10.20.30.254', 'ttl': 64, 'size': 76, 'rtt': 1.577}, {'from': '10.20.30.254', 'ttl': 64, 'size': 76, 'rtt': 0.575}, {'from': '10.20.30.254', 'ttl': 64, 'size': 76, 'rtt': 0.574}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 9.12}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 5.609}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 7.303}]}], 'msm_id': 30460770, 'prb_id': 32368, 'timestamp': 1622307475, 'msm_name': 'Traceroute', 'from': '70.106.194.253', 'type': 'traceroute', 'group_id': 30460770, 'stored_timestamp': 1622307476}
#
# ProbeID:  4720
# {'fw': 4790, 'lts': 85, 'endtime': 1622307540, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '192.168.22.11', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '192.168.22.1', 'ttl': 255, 'size': 28, 'rtt': 8.281}, {'from': '192.168.22.1', 'ttl': 255, 'size': 28, 'rtt': 2.241}, {'from': '192.168.22.1', 'ttl': 255, 'size': 28, 'rtt': 2.25}]}, {'hop': 2, 'result': [{'x': '*'}, {'x': '*'}, {'x': '*'}]}, {'hop': 3, 'result': [{'x': '*'}, {'x': '*'}, {'x': '*'}]}, {'hop': 4, 'result': [{'x': '*'}, {'x': '*'}, {'x': '*'}]}, {'hop': 5, 'result': [{'x': '*'}, {'x': '*'}, {'x': '*'}]}, {'hop': 6, 'result': [{'x': '*'}, {'x': '*'}, {'x': '*'}]}, {'hop': 255, 'result': [{'from': '147.28.14.1', 'ttl': 45, 'size': 48, 'rtt': 232.407}, {'from': '147.28.14.1', 'ttl': 45, 'size': 48, 'rtt': 232.868}, {'from': '147.28.14.1', 'ttl': 45, 'size': 48, 'rtt': 232.021}]}], 'msm_id': 30460770, 'prb_id': 4720, 'timestamp': 1622307480, 'msm_name': 'Traceroute', 'from': '103.47.184.187', 'type': 'traceroute', 'group_id': 30460770, 'stored_timestamp': 1622307541}
#
# ProbeID:  50294
# {'fw': 5020, 'mver': '2.2.1', 'lts': 45, 'endtime': 1622307478, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '192.168.1.96', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 1.28}, {'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 0.738}, {'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 0.62}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 66, 'size': 48, 'rtt': 152.927}, {'from': '147.28.14.1', 'ttl': 66, 'size': 48, 'rtt': 134.811}, {'from': '147.28.14.1', 'ttl': 66, 'size': 48, 'rtt': 200.905}]}], 'msm_id': 30460771, 'prb_id': 50294, 'timestamp': 1622307477, 'msm_name': 'Traceroute', 'from': '172.58.207.124', 'type': 'traceroute', 'group_id': 30460771, 'stored_timestamp': 1622307478}
#
# ProbeID:  28794
# {'fw': 5020, 'mver': '2.2.1', 'lts': 47, 'endtime': 1622307486, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '192.168.3.187', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '192.168.3.1', 'ttl': 64, 'size': 76, 'rtt': 0.815}, {'from': '192.168.3.1', 'ttl': 64, 'size': 76, 'rtt': 0.43}, {'from': '192.168.3.1', 'ttl': 64, 'size': 76, 'rtt': 0.395}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 7.893}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 8.596}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 11.351}]}], 'msm_id': 30460770, 'prb_id': 28794, 'timestamp': 1622307486, 'msm_name': 'Traceroute', 'from': '108.51.83.226', 'type': 'traceroute', 'group_id': 30460770, 'stored_timestamp': 1622307488}
#
# ProbeID:  3715
# {'fw': 4790, 'lts': 1, 'endtime': 1622307477, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '192.168.3.189', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '192.168.3.1', 'ttl': 64, 'size': 76, 'rtt': 7.44}, {'from': '192.168.3.1', 'ttl': 64, 'size': 76, 'rtt': 1.215}, {'from': '192.168.3.1', 'ttl': 64, 'size': 76, 'rtt': 1.181}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'rtt': 3.982}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'rtt': 3.906}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'rtt': 3.911}]}], 'msm_id': 30460770, 'prb_id': 3715, 'timestamp': 1622307477, 'msm_name': 'Traceroute', 'from': '71.126.140.145', 'type': 'traceroute', 'group_id': 30460770, 'stored_timestamp': 1622307477}
#
# ProbeID:  10371
# {'fw': 5020, 'mver': '2.2.1', 'lts': 28, 'endtime': 1622307480, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '192.168.21.172', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '192.168.20.1', 'ttl': 64, 'size': 76, 'rtt': 0.599}, {'from': '192.168.20.1', 'ttl': 64, 'size': 76, 'rtt': 0.415}, {'from': '192.168.20.1', 'ttl': 64, 'size': 76, 'rtt': 0.301}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 1.136}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 0.885}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 0.968}]}], 'msm_id': 30460770, 'prb_id': 10371, 'timestamp': 1622307480, 'msm_name': 'Traceroute', 'from': '74.101.37.109', 'type': 'traceroute', 'group_id': 30460770, 'stored_timestamp': 1622307480}
#
# ProbeID:  33415
# {'fw': 5020, 'mver': '2.2.1', 'lts': 124, 'endtime': 1622307477, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '192.168.0.88', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '192.168.0.1', 'ttl': 64, 'size': 76, 'rtt': 1.795}, {'from': '192.168.0.1', 'ttl': 64, 'size': 76, 'rtt': 0.42}, {'from': '192.168.0.1', 'ttl': 64, 'size': 76, 'rtt': 0.434}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 5.251}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 2.703}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 6.037}]}], 'msm_id': 30460771, 'prb_id': 33415, 'timestamp': 1622307476, 'msm_name': 'Traceroute', 'from': '71.126.173.34', 'type': 'traceroute', 'group_id': 30460771, 'stored_timestamp': 1622307477}
#
# ProbeID:  25225
# {'fw': 5020, 'mver': '2.2.1', 'lts': 25, 'endtime': 1622307479, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '10.0.3.252', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '10.0.3.1', 'ttl': 64, 'size': 76, 'rtt': 1.36}, {'from': '10.0.3.1', 'ttl': 64, 'size': 76, 'rtt': 0.623}, {'from': '10.0.3.1', 'ttl': 64, 'size': 76, 'rtt': 0.588}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 47, 'size': 48, 'rtt': 79.258}, {'from': '147.28.14.1', 'ttl': 47, 'size': 48, 'rtt': 83.433}, {'from': '147.28.14.1', 'ttl': 47, 'size': 48, 'rtt': 82.707}]}], 'msm_id': 30460770, 'prb_id': 25225, 'timestamp': 1622307479, 'msm_name': 'Traceroute', 'from': '46.134.131.175', 'type': 'traceroute', 'group_id': 30460770, 'stored_timestamp': 1622307480}
#
# ProbeID:  20625
# {'fw': 5020, 'mver': '2.2.1', 'lts': 29, 'endtime': 1622307477, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '192.168.1.211', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 0.704}, {'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 0.511}, {'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 0.761}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 2.32}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 1.727}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 3.76}]}], 'msm_id': 30460770, 'prb_id': 20625, 'timestamp': 1622307477, 'msm_name': 'Traceroute', 'from': '68.129.175.174', 'type': 'traceroute', 'group_id': 30460770, 'stored_timestamp': 1622307477}
#
# ProbeID:  24725
# {'fw': 5020, 'mver': '2.2.1', 'lts': 42, 'endtime': 1622307480, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '192.168.4.48', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '192.168.4.1', 'ttl': 64, 'size': 76, 'rtt': 0.673}, {'from': '192.168.4.1', 'ttl': 64, 'size': 76, 'rtt': 0.534}, {'from': '192.168.4.1', 'ttl': 64, 'size': 76, 'rtt': 0.533}]}, {'hop': 2, 'result': [{'from': '192.168.1.1', 'ttl': 63, 'size': 76, 'rtt': 0.896}, {'from': '192.168.1.1', 'ttl': 63, 'size': 76, 'rtt': 0.753}, {'from': '192.168.1.1', 'ttl': 63, 'size': 76, 'rtt': 0.718}]}, {'hop': 3, 'result': [{'from': '147.28.14.1', 'ttl': 253, 'size': 48, 'tos': 192, 'rtt': 1.787}, {'from': '147.28.14.1', 'ttl': 253, 'size': 48, 'tos': 192, 'rtt': 1.856}, {'from': '147.28.14.1', 'ttl': 253, 'size': 48, 'tos': 192, 'rtt': 1.779}]}], 'msm_id': 30460770, 'prb_id': 24725, 'timestamp': 1622307480, 'msm_name': 'Traceroute', 'from': '71.241.253.36', 'type': 'traceroute', 'group_id': 30460770, 'stored_timestamp': 1622307480}
#
# ProbeID:  52374
# {'fw': 5020, 'mver': '2.2.1', 'lts': 43, 'endtime': 1622307476, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '192.168.1.188', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 1.539}, {'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 1.131}, {'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 0.903}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 2.567}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 3.397}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 5.452}]}], 'msm_id': 30460771, 'prb_id': 52374, 'timestamp': 1622307476, 'msm_name': 'Traceroute', 'from': '71.184.133.91', 'type': 'traceroute', 'group_id': 30460771, 'stored_timestamp': 1622307477}
#
# ProbeID:  3737
# {'fw': 4790, 'lts': 11, 'endtime': 1622307487, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '192.168.1.151', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 7.405}, {'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 1.183}, {'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 1.135}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'rtt': 5.636}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'rtt': 4.435}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'rtt': 4.801}]}], 'msm_id': 30460770, 'prb_id': 3737, 'timestamp': 1622307487, 'msm_name': 'Traceroute', 'from': '173.79.138.200', 'type': 'traceroute', 'group_id': 30460770, 'stored_timestamp': 1622307488}
#
# ProbeID:  28315
# {'fw': 5020, 'mver': '2.2.1', 'lts': 74, 'endtime': 1622307550, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '192.168.30.244', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '192.168.30.1', 'ttl': 64, 'size': 76, 'rtt': 1.564}, {'from': '192.168.30.1', 'ttl': 64, 'size': 76, 'rtt': 0.655}, {'from': '192.168.30.1', 'ttl': 64, 'size': 76, 'rtt': 0.623}]}, {'hop': 2, 'result': [{'from': '10.23.0.1', 'ttl': 254, 'size': 28, 'rtt': 7.322}, {'from': '10.23.0.1', 'ttl': 254, 'size': 28, 'rtt': 8.731}, {'from': '10.23.0.1', 'ttl': 254, 'size': 28, 'rtt': 9.632}]}, {'hop': 3, 'result': [{'from': '213.221.237.42', 'ttl': 253, 'size': 68, 'rtt': 13.85}, {'from': '213.221.237.42', 'ttl': 253, 'size': 68, 'rtt': 9.868}, {'from': '213.221.237.42', 'ttl': 253, 'size': 68, 'rtt': 9.564}]}, {'hop': 4, 'result': [{'x': '*'}, {'x': '*'}, {'x': '*'}]}, {'hop': 5, 'result': [{'x': '*'}, {'x': '*'}, {'x': '*'}]}, {'hop': 6, 'result': [{'x': '*'}, {'x': '*'}, {'x': '*'}]}, {'hop': 7, 'result': [{'x': '*'}, {'x': '*'}, {'x': '*'}]}, {'hop': 8, 'result': [{'from': '147.28.14.1', 'ttl': 60, 'size': 48, 'rtt': 54.455}, {'from': '147.28.14.1', 'ttl': 60, 'size': 48, 'rtt': 55.81}, {'from': '147.28.14.1', 'ttl': 60, 'size': 48, 'rtt': 55.8}]}], 'msm_id': 30460770, 'prb_id': 28315, 'timestamp': 1622307501, 'msm_name': 'Traceroute', 'from': '178.197.233.50', 'type': 'traceroute', 'group_id': 30460770, 'stored_timestamp': 1622307550}
#
# ProbeID:  51868
# {'fw': 5020, 'mver': '2.2.1', 'lts': 32, 'endtime': 1622307482, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '192.168.4.2', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '192.168.4.1', 'ttl': 64, 'size': 76, 'rtt': 1.194}, {'from': '192.168.4.1', 'ttl': 64, 'size': 76, 'rtt': 0.664}, {'from': '192.168.4.1', 'ttl': 64, 'size': 76, 'rtt': 0.592}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 2.514}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 1.477}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 2.241}]}], 'msm_id': 30460771, 'prb_id': 51868, 'timestamp': 1622307482, 'msm_name': 'Traceroute', 'from': '96.245.183.181', 'type': 'traceroute', 'group_id': 30460771, 'stored_timestamp': 1622307483}
#
# ProbeID:  31389
# {'fw': 5020, 'mver': '2.2.1', 'lts': 25, 'endtime': 1622307479, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '192.168.29.83', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '192.168.29.1', 'ttl': 64, 'size': 76, 'rtt': 0.545}, {'from': '192.168.29.1', 'ttl': 64, 'size': 76, 'rtt': 0.366}, {'from': '192.168.29.1', 'ttl': 64, 'size': 76, 'rtt': 0.307}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 1.279}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 65.331}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 65.903}]}], 'msm_id': 30460770, 'prb_id': 31389, 'timestamp': 1622307479, 'msm_name': 'Traceroute', 'from': '100.36.177.74', 'type': 'traceroute', 'group_id': 30460770, 'stored_timestamp': 1622307480}
#
# ProbeID:  54945
# {'fw': 5020, 'mver': '2.2.1', 'lts': 6, 'endtime': 1622307478, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '10.10.10.19', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '10.10.10.1', 'ttl': 64, 'size': 76, 'rtt': 1.3}, {'from': '10.10.10.1', 'ttl': 64, 'size': 76, 'rtt': 0.717}, {'from': '10.10.10.1', 'ttl': 64, 'size': 76, 'rtt': 0.622}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 1.642}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 2.211}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 1.416}]}], 'msm_id': 30460771, 'prb_id': 54945, 'timestamp': 1622307478, 'msm_name': 'Traceroute', 'from': '70.106.252.23', 'type': 'traceroute', 'group_id': 30460771, 'stored_timestamp': 1622307479}
#
# ProbeID:  55457
# {'fw': 5020, 'mver': '2.2.1', 'lts': 59, 'endtime': 1622307492, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '192.168.1.35', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '192.168.0.1', 'ttl': 64, 'size': 28, 'rtt': 1.092}, {'from': '192.168.0.1', 'ttl': 64, 'size': 28, 'rtt': 0.595}, {'from': '192.168.0.1', 'ttl': 64, 'size': 28, 'rtt': 0.539}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 3.69}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 4.471}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 3.704}]}], 'msm_id': 30460771, 'prb_id': 55457, 'timestamp': 1622307492, 'msm_name': 'Traceroute', 'from': '108.28.101.106', 'type': 'traceroute', 'group_id': 30460771, 'stored_timestamp': 1622307497}
#
# ProbeID:  3756
# {'fw': 4790, 'lts': 5, 'endtime': 1622307482, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '172.24.1.228', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '172.24.1.1', 'ttl': 64, 'size': 76, 'rtt': 7.625}, {'from': '172.24.1.1', 'ttl': 64, 'size': 76, 'rtt': 1.177}, {'from': '172.24.1.1', 'ttl': 64, 'size': 76, 'rtt': 1.129}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'rtt': 2.468}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'rtt': 3.869}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'rtt': 2.278}]}], 'msm_id': 30460770, 'prb_id': 3756, 'timestamp': 1622307482, 'msm_name': 'Traceroute', 'from': '71.162.145.158', 'type': 'traceroute', 'group_id': 30460770, 'stored_timestamp': 1622307482}
#
# ProbeID:  3767
# {'fw': 4790, 'lts': 66, 'endtime': 1622307480, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '192.168.1.24', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 7.695}, {'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 4.303}, {'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 4.338}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'rtt': 18.503}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'rtt': 14.772}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'rtt': 12.031}]}], 'msm_id': 30460770, 'prb_id': 3767, 'timestamp': 1622307480, 'msm_name': 'Traceroute', 'from': '173.48.105.206', 'type': 'traceroute', 'group_id': 30460770, 'stored_timestamp': 1622307480}
#
# ProbeID:  51389
# {'fw': 5020, 'mver': '2.2.1', 'lts': 115, 'endtime': 1622307477, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '192.168.99.1', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '192.168.99.0', 'ttl': 64, 'size': 76, 'rtt': 1.602}, {'from': '192.168.99.0', 'ttl': 64, 'size': 76, 'rtt': 0.639}, {'from': '192.168.99.0', 'ttl': 64, 'size': 76, 'rtt': 0.583}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 6.685}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 3.326}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 1.437}]}], 'msm_id': 30460771, 'prb_id': 51389, 'timestamp': 1622307477, 'msm_name': 'Traceroute', 'from': '74.102.202.234', 'type': 'traceroute', 'group_id': 30460771, 'stored_timestamp': 1622307478}
#
# ProbeID:  22720
# {'fw': 5020, 'mver': '2.2.1', 'lts': 12, 'endtime': 1622307477, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '172.28.9.74', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '172.28.9.1', 'ttl': 64, 'size': 76, 'rtt': 1.549}, {'from': '172.28.9.1', 'ttl': 64, 'size': 76, 'rtt': 0.572}, {'from': '172.28.9.1', 'ttl': 64, 'size': 76, 'rtt': 0.534}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 2.098}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 1.783}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 1.899}]}], 'msm_id': 30460770, 'prb_id': 22720, 'timestamp': 1622307477, 'msm_name': 'Traceroute', 'from': '71.185.60.115', 'type': 'traceroute', 'group_id': 30460770, 'stored_timestamp': 1622307478}
#
# ProbeID:  23749
# {'fw': 5020, 'mver': '2.2.1', 'lts': 43, 'endtime': 1622307479, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '192.168.1.180', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 0.845}, {'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 0.592}, {'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 0.538}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 6.762}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 8.95}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 9.74}]}], 'msm_id': 30460770, 'prb_id': 23749, 'timestamp': 1622307479, 'msm_name': 'Traceroute', 'from': '100.36.38.178', 'type': 'traceroute', 'group_id': 30460770, 'stored_timestamp': 1622307480}
#
# ProbeID:  29383
# ...
#
# ProbeID:  32704
# {'fw': 5020, 'mver': '2.2.1', 'lts': 26, 'endtime': 1622307480, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '10.0.10.31', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '10.0.10.1', 'ttl': 64, 'size': 76, 'rtt': 0.952}, {'x': '*'}, {'from': '10.0.10.1', 'ttl': 64, 'size': 76, 'rtt': 0.545}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 2.94}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 8.322}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 9.376}]}], 'msm_id': 30460770, 'prb_id': 32704, 'timestamp': 1622307476, 'msm_name': 'Traceroute', 'from': '100.1.10.233', 'type': 'traceroute', 'group_id': 30460770, 'stored_timestamp': 1622307482}
#
# ProbeID:  55744
# {'fw': 5020, 'mver': '2.2.1', 'lts': 21, 'endtime': 1622307481, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '192.168.1.186', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 1.074}, {'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 0.592}, {'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 0.536}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 4.255}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 3.049}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 1.694}]}], 'msm_id': 30460771, 'prb_id': 55744, 'timestamp': 1622307481, 'msm_name': 'Traceroute', 'from': '71.178.26.102', 'type': 'traceroute', 'group_id': 30460771, 'stored_timestamp': 1622307483}
#
# ProbeID:  55235
# {'fw': 5020, 'mver': '2.2.1', 'lts': 34, 'endtime': 1622307486, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '192.168.1.220', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 1.389}, {'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 0.791}, {'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 0.743}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 2.466}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 2.629}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 2.411}]}], 'msm_id': 30460771, 'prb_id': 55235, 'timestamp': 1622307486, 'msm_name': 'Traceroute', 'from': '72.82.149.169', 'type': 'traceroute', 'group_id': 30460771, 'stored_timestamp': 1622307487}
#
# ProbeID:  50117
# {'fw': 5020, 'mver': '2.2.1', 'lts': 32, 'endtime': 1622307477, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '192.168.1.136', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 1.069}, {'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 0.71}, {'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 0.674}]}, {'hop': 2, 'result': [{'from': '192.168.199.1', 'ttl': 63, 'size': 76, 'rtt': 1.154}, {'from': '192.168.199.1', 'ttl': 63, 'size': 76, 'rtt': 1.008}, {'from': '192.168.199.1', 'ttl': 63, 'size': 76, 'rtt': 0.801}]}, {'hop': 3, 'result': [{'from': '147.28.14.1', 'ttl': 253, 'size': 48, 'tos': 192, 'rtt': 3.147}, {'from': '147.28.14.1', 'ttl': 253, 'size': 48, 'tos': 192, 'rtt': 3.562}, {'from': '147.28.14.1', 'ttl': 253, 'size': 48, 'tos': 192, 'rtt': 2.177}]}], 'msm_id': 30460771, 'prb_id': 50117, 'timestamp': 1622307477, 'msm_name': 'Traceroute', 'from': '173.79.122.110', 'type': 'traceroute', 'group_id': 30460771, 'stored_timestamp': 1622307477}
#
# ProbeID:  54215
# {'fw': 5020, 'mver': '2.2.1', 'lts': 15, 'endtime': 1622307479, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '172.16.128.13', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '172.16.128.1', 'ttl': 64, 'size': 64, 'rtt': 1.393}, {'from': '172.16.128.1', 'ttl': 64, 'size': 64, 'rtt': 0.786}, {'from': '172.16.128.1', 'ttl': 64, 'size': 64, 'rtt': 0.69}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 1.713}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 1.537}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 1.616}]}], 'msm_id': 30460771, 'prb_id': 54215, 'timestamp': 1622307479, 'msm_name': 'Traceroute', 'from': '96.249.148.36', 'type': 'traceroute', 'group_id': 30460771, 'stored_timestamp': 1622307480}
#
# ProbeID:  18898
# {'fw': 5020, 'mver': '2.2.1', 'lts': 52, 'endtime': 1622307489, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '192.168.1.231', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 1.548}, {'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 0.523}, {'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 0.45}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 1.367}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 1.435}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 1.577}]}], 'msm_id': 30460770, 'prb_id': 18898, 'timestamp': 1622307489, 'msm_name': 'Traceroute', 'from': '100.16.202.152', 'type': 'traceroute', 'group_id': 30460770, 'stored_timestamp': 1622307490}
#
# ProbeID:  34275
# {'fw': 5020, 'mver': '2.2.1', 'lts': 23, 'endtime': 1622307476, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '172.30.251.125', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '172.30.250.1', 'ttl': 64, 'size': 76, 'rtt': 1.091}, {'from': '172.30.250.1', 'ttl': 64, 'size': 76, 'rtt': 0.382}, {'from': '172.30.250.1', 'ttl': 64, 'size': 76, 'rtt': 0.368}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 1.303}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 6.813}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 5.789}]}], 'msm_id': 30460771, 'prb_id': 34275, 'timestamp': 1622307476, 'msm_name': 'Traceroute', 'from': '173.72.151.195', 'type': 'traceroute', 'group_id': 30460771, 'stored_timestamp': 1622307478}
#
# ProbeID:  27108
# {'fw': 5020, 'mver': '2.2.1', 'lts': 4, 'endtime': 1622307534, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '172.16.1.58', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '172.16.1.1', 'ttl': 64, 'size': 76, 'rtt': 1.562}, {'from': '172.16.1.1', 'ttl': 64, 'size': 76, 'rtt': 0.503}, {'from': '172.16.1.1', 'ttl': 64, 'size': 76, 'rtt': 0.496}]}, {'hop': 2, 'result': [{'from': '192.168.1.1', 'ttl': 63, 'size': 76, 'rtt': 0.962}, {'x': '*'}, {'from': '192.168.1.1', 'ttl': 63, 'size': 76, 'rtt': 0.858}]}, {'hop': 3, 'result': [{'from': '2.187.0.222', 'ttl': 253, 'size': 28, 'rtt': 51.531}, {'from': '2.187.0.222', 'ttl': 253, 'size': 28, 'rtt': 21.253}, {'from': '2.187.0.222', 'ttl': 253, 'size': 28, 'rtt': 29.195}]}, {'hop': 4, 'result': [{'x': '*'}, {'x': '*'}, {'x': '*'}]}, {'hop': 5, 'result': [{'from': '80.210.16.65', 'ttl': 251, 'size': 28, 'rtt': 28.115}, {'from': '80.210.16.65', 'ttl': 251, 'size': 28, 'rtt': 28.206}, {'from': '80.210.16.65', 'ttl': 251, 'size': 28, 'rtt': 26.476}]}, {'hop': 6, 'result': [{'x': '*'}, {'x': '*'}, {'from': '10.21.249.201', 'ttl': 250, 'size': 28, 'rtt': 27.482}]}, {'hop': 7, 'result': [{'from': '10.202.6.90', 'ttl': 249, 'size': 68, 'rtt': 30.642}, {'from': '10.202.6.90', 'ttl': 249, 'size': 68, 'rtt': 27.624}, {'from': '10.202.6.90', 'ttl': 249, 'size': 68, 'rtt': 34.703}]}, {'hop': 8, 'result': [{'from': '10.21.0.10', 'ttl': 248, 'size': 68, 'rtt': 29.118}, {'from': '10.21.0.10', 'ttl': 248, 'size': 68, 'rtt': 28.284}, {'from': '10.21.0.10', 'ttl': 248, 'size': 68, 'rtt': 28.444}]}, {'hop': 9, 'result': [{'from': '10.21.0.10', 'ttl': 248, 'size': 68, 'rtt': 28.975}, {'from': '10.21.0.10', 'ttl': 248, 'size': 68, 'rtt': 27.602}, {'from': '10.21.0.10', 'ttl': 248, 'size': 68, 'rtt': 28.03}]}, {'hop': 10, 'result': [{'from': '193.251.252.153', 'ttl': 244, 'size': 28, 'rtt': 101.634}, {'from': '193.251.252.153', 'ttl': 244, 'size': 28, 'rtt': 101.071}, {'from': '193.251.252.153', 'ttl': 244, 'size': 28, 'rtt': 100.733}]}, {'hop': 11, 'result': [{'from': '193.251.132.163', 'ttl': 244, 'size': 28, 'rtt': 172.22}, {'from': '193.251.132.163', 'ttl': 244, 'size': 28, 'rtt': 145.895}, {'from': '193.251.132.163', 'ttl': 244, 'size': 28, 'rtt': 141.791}]}, {'hop': 12, 'result': [{'from': '193.251.247.156', 'ttl': 241, 'size': 68, 'rtt': 141.152}, {'from': '193.251.247.156', 'ttl': 241, 'size': 68, 'rtt': 141.605}, {'from': '193.251.247.156', 'ttl': 241, 'size': 68, 'rtt': 142.805}]}, {'hop': 13, 'result': [{'from': '129.250.6.50', 'ttl': 241, 'size': 28, 'rtt': 142.635}, {'from': '129.250.6.50', 'ttl': 241, 'size': 28, 'rtt': 142.423}, {'from': '129.250.6.50', 'ttl': 241, 'size': 28, 'rtt': 143.496}]}, {'hop': 14, 'result': [{'from': '129.250.3.77', 'ttl': 241, 'size': 28, 'rtt': 106.746}, {'from': '129.250.3.77', 'ttl': 241, 'size': 28, 'rtt': 106.6}, {'from': '129.250.3.77', 'ttl': 241, 'size': 28, 'rtt': 110.617}]}, {'hop': 15, 'result': [{'from': '129.250.7.89', 'ttl': 243, 'size': 28, 'rtt': 109.757}, {'from': '129.250.7.89', 'ttl': 243, 'size': 28, 'rtt': 107.706}, {'from': '129.250.7.89', 'ttl': 243, 'size': 28, 'rtt': 107.774}]}, {'hop': 16, 'result': [{'from': '83.231.213.58', 'ttl': 242, 'size': 28, 'rtt': 108.77}, {'from': '83.231.213.58', 'ttl': 242, 'size': 28, 'rtt': 107.951}, {'from': '83.231.213.58', 'ttl': 242, 'size': 28, 'rtt': 109.817}]}, {'hop': 17, 'result': [{'from': '213.136.1.74', 'ttl': 241, 'size': 28, 'rtt': 108.382}, {'from': '213.136.1.74', 'ttl': 241, 'size': 28, 'rtt': 108.949}, {'from': '213.136.1.74', 'ttl': 241, 'size': 28, 'rtt': 108.235}]}, {'hop': 18, 'result': [{'x': '*'}, {'x': '*'}, {'x': '*'}]}, {'hop': 19, 'result': [{'from': '147.28.14.1', 'ttl': 50, 'size': 48, 'rtt': 133.581}, {'from': '147.28.14.1', 'ttl': 50, 'size': 48, 'rtt': 133.06}, {'from': '147.28.14.1', 'ttl': 50, 'size': 48, 'rtt': 133.096}]}], 'msm_id': 30460770, 'prb_id': 27108, 'timestamp': 1622307494, 'msm_name': 'Traceroute', ...
#
# ProbeID:  1000424
# {'fw': 5010, 'mver': '2.2.0', 'lts': 21, 'endtime': 1622307541, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '192.168.1.4', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 18.813}, {'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 18.327}, {'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 18.902}]}, {'hop': 2, 'result': [{'x': '*'}, {'x': '*'}, {'x': '*'}]}, {'hop': 3, 'result': [{'from': '192.168.4.18', 'ttl': 253, 'size': 68, 'rtt': 32.427}, {'from': '192.168.4.18', 'ttl': 253, 'size': 68, 'rtt': 33.57}, {'from': '192.168.4.18', 'ttl': 253, 'size': 68, 'rtt': 33.721}]}, {'hop': 4, 'result': [{'from': '147.28.14.1', 'ttl': 46, 'size': 48, 'rtt': 91.313}, {'from': '147.28.14.1', 'ttl': 46, 'size': 48, 'rtt': 92.526}, {'from': '147.28.14.1', 'ttl': 46, 'size': 48, 'rtt': 92.204}]}], 'msm_id': 30460771, 'prb_id': 1000424, 'timestamp': 1622307528, 'msm_name': 'Traceroute', 'from': '212.113.188.217', 'type': 'traceroute', 'group_id': 30460771, 'stored_timestamp': 1622307541}
#
# ProbeID:  32234
# {'fw': 4760, 'lts': 33, 'endtime': 1622307476, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '192.168.1.16', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 1.619}, {'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 0.416}, {'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 0.754}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'rtt': 4.352}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'rtt': 4.181}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'rtt': 4.299}]}], 'msm_id': 30460770, 'prb_id': 32234, 'timestamp': 1622307476, 'msm_name': 'Traceroute', 'from': '108.28.124.120', 'type': 'traceroute', 'group_id': 30460770, 'stored_timestamp': 1622307478}
#
# ProbeID:  50164
# {'fw': 5020, 'mver': '2.2.1', 'lts': 25, 'endtime': 1622307478, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '172.19.74.147', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '172.19.74.1', 'ttl': 64, 'size': 76, 'rtt': 1.227}, {'from': '172.19.74.1', 'ttl': 64, 'size': 76, 'rtt': 0.784}, {'from': '172.19.74.1', 'ttl': 64, 'size': 76, 'rtt': 0.708}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 7.918}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 8.237}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 5.674}]}], 'msm_id': 30460771, 'prb_id': 50164, 'timestamp': 1622307478, 'msm_name': 'Traceroute', 'from': '71.163.80.119', 'type': 'traceroute', 'group_id': 30460771, 'stored_timestamp': 1622307478}
#
# ProbeID:  51703
# {'fw': 5020, 'mver': '2.2.1', 'lts': 8, 'endtime': 1622307480, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '10.47.9.50', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '10.47.9.1', 'ttl': 64, 'size': 76, 'rtt': 4.025}, {'from': '10.47.9.1', 'ttl': 64, 'size': 76, 'rtt': 0.74}, {'from': '10.47.9.1', 'ttl': 64, 'size': 76, 'rtt': 0.555}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 1.944}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 2.083}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 1.388}]}], 'msm_id': 30460771, 'prb_id': 51703, 'timestamp': 1622307480, 'msm_name': 'Traceroute', 'from': '96.241.116.16', 'type': 'traceroute', 'group_id': 30460771, 'stored_timestamp': 1622307480}
#
# ProbeID:  28154
# {'fw': 5020, 'mver': '2.2.1', 'lts': 23, 'endtime': 1622307476, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '192.168.1.5', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 1.548}, {'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 0.546}, {'from': '192.168.1.1', 'ttl': 64, 'size': 76, 'rtt': 0.579}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 8.459}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 6.834}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 17.386}]}], 'msm_id': 30460770, 'prb_id': 28154, 'timestamp': 1622307476, 'msm_name': 'Traceroute', 'from': '98.110.114.25', 'type': 'traceroute', 'group_id': 30460770, 'stored_timestamp': 1622307478}
#
# ProbeID:  17403
# {'fw': 5020, 'mver': '2.2.1', 'lts': 27, 'endtime': 1622307487, 'dst_name': '147.28.14.1', 'dst_addr': '147.28.14.1', 'src_addr': '192.168.147.196', 'proto': 'ICMP', 'af': 4, 'size': 48, 'paris_id': 1, 'result': [{'hop': 1, 'result': [{'from': '192.168.147.254', 'ttl': 64, 'size': 76, 'rtt': 1.091}, {'from': '192.168.147.254', 'ttl': 64, 'size': 76, 'rtt': 0.367}, {'from': '192.168.147.254', 'ttl': 64, 'size': 76, 'rtt': 0.301}]}, {'hop': 2, 'result': [{'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 8.111}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 4.681}, {'from': '147.28.14.1', 'ttl': 254, 'size': 48, 'tos': 192, 'rtt': 4.722}]}], 'msm_id': 30460770, 'prb_id': 17403, 'timestamp': 1622307487, 'msm_name': 'Traceroute', 'from': '108.7.188.190', 'type': 'traceroute', 'group_id': 30460770, 'stored_timestamp': 1622307493}
